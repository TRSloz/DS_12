# %% [markdown]
# ___
#
# <a href='https://mainacademy.ua/'> <img src='https://mainacademy.ua/wp-content/uploads/2019/03/logo-main.png' alt = 'Хмм, щось з інтернетом'/></a>
# ___
#
# # Module 5: Data analysis with NumPy and Pandas

# %% [markdown]
# ## Lab work 5.1

# %% [markdown]
# #### Мета:
#
# * навчитися працювати із бібліотекою NumPy в Python

# %% [markdown]
# ### Завдання:

# %%
import numpy as np

# %% [markdown]
# Вивести версію та конфігурацію бібліотеки:

# %%
print(np.__version__)
print(np.show_config())
# Out:
# 1.21.5
# blas_mkl_info:
#   NOT AVAILABLE
# blis_info:
#   NOT AVAILABLE
# openblas_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
#     runtime_library_dirs = ['/usr/local/lib']
# blas_opt_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
#     runtime_library_dirs = ['/usr/local/lib']
# lapack_mkl_info:
#   NOT AVAILABLE
# openblas_lapack_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
#     runtime_library_dirs = ['/usr/local/lib']
# lapack_opt_info:
#     libraries = ['openblas', 'openblas']
#     library_dirs = ['/usr/local/lib']
#     language = c
#     define_macros = [('HAVE_CBLAS', None)]
#     runtime_library_dirs = ['/usr/local/lib']
# Supported SIMD extensions in this NumPy install:
#     baseline = SSE,SSE2,SSE3
#     found = SSSE3,SSE41,POPCNT,SSE42,AVX,F16C,FMA3,AVX2
#     not found = AVX512F,AVX512CD,AVX512_KNL,AVX512_KNM,AVX512_SKX,AVX512_CLX,AVX512_CNL,AVX512_ICL
# None

# %% [markdown]
# Створити вектор з 10 елементів, заповнений одиницями:

# %%
v1 = np.ones(10)
v1

# %% [markdown]
# Створити вектор із значеннями від 0 до 10:

# %%
v2 = np.arange(0,11)
v2

# %% [markdown]
# Створити матрицю 5 на 5, заповнену нулями:

# %%
m1 = np.zeros((5,5))
m1

# %% [markdown]
# Заповнити вектор з 20 елементів випадковими цілими числами. Знайти індекси ненульових елементів:

# %%
rv1 = np.random.randint(0,10,20)
np.where(rv1 == 0)[0]

# %% [markdown]
# Для вектора із попередньої задачі знайти середнє значення, медіану, стандартне відхилення:

# %%
print(f'Mean   - {rv1.mean()}')
print(f'Median - {np.median(rv1)}')
print(f'Std    - {rv1.std()}')
# Out:
# Mean   - 3.75
# Median - 4.0
# Std    - 2.277608394786075

# %% [markdown]
# Створити дві матриці випадкових чисел розміром 4х2 та 2х2. Перемножити їх:

# %%
M2 = np.random.randint(0,100,(4,2))
M3 = np.random.randint(0,100,(2,2))
M4 = M2.dot(M3)
M4

# %% [markdown]
# Результуючу матрицю із попередньої задачі перетворити у вектор. Знайти мінімальне та максимальне значення.
#
# Максимальне значення замінити на 0:

# %%
M4.ravel()

# %%
print(f'Min - {M4.min()}')
print(f'Max - {M4.max()}')

indMax = np.unravel_index(M4.argmax(), shape=M4.shape)
M4[indMax] = 0
M4
# Out:
# Min - 2484
# Max - 14449

# %% [markdown]
# Знайдіть кореляцію першого рядка матриці із попереднього завдання із іншими рядками:

# %%
print('Correlation -')
np.corrcoef(M4)
# Out:
# Correlation -

# %% [markdown]
# Дано матрицю. Знайти ранг матриці:

# %%
a = np.array([[ 1,  4, 5],
              [7, 3, 2],
              [9, 16, 1]])

print(f'Rank - {np.linalg.matrix_rank(a)}')
# Out:
# Rank - 3

# %% [markdown]
# Знайти визначник матриці:

# %%
print(f'Determinant - {np.linalg.det(a)}')
# Out:
# Determinant - 440.0000000000002

# %% [markdown]
# Знайти власні значення та власні вектори матриці:

# %%
wb, vb = np.linalg.eigh(a)
wb

# %%
vb

# %% [markdown]
# Знайдіть число, що найчастіше зустрічається в масиві:

# %%
a = np.random.randint(0,10,50)
bc = np.bincount(a)
mod_fq = bc.max()
moda = np.where(bc == mod_fq)[0]
moda

# %% [markdown]
# Виведіть лише парні числа, що діляться на 5:

# %%
print(a[(a % 2 == 0) & (a % 5 == 0)])
# Out:
# [0 0 0 0 0]

# %% [markdown]
# Розв'яжіть систему рівнянь:
# $$2x + 5y = 1 $$
#
# $$x - 10y = 3  $$

# %%
A = np.array(((2, 5), (1, -10)))
b = np.array((1, 3))

x = np.linalg.solve(A, b)
x
